# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLO11 Object Detection on a Custom Dataset
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# YOLO11 builds on the advancements introduced in YOLOv9 and YOLOv10 earlier this year, incorporating improved architectural designs, enhanced feature extraction techniques, and optimized training methods.
#
# YOLO11m achieves a higher mean mAP score on the COCO dataset while using 22% fewer parameters than YOLOv8m, making it computationally lighter without sacrificing performance.
#
# YOLOv11 is available in 5 different sizes, ranging from `2.6M` to `56.9M` parameters, and capable of achieving from `39.5` to `54.7` mAP on the COCO dataset.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Mar 20 13:25:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %% [markdown]
# ## Inference with model pre-trained on COCO dataset

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### CLI
#
# **NOTE:** CLI requires no customization or Python code. You can simply run all tasks from the terminal with the yolo command.

# %%
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 84.6MB/s]
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 68.4MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 47.2ms
# Speed: 21.0ms preprocess, 47.2ms inference, 354.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Result annotated image got saved in `{HOME}/runs/detect/predict/`. Let's display it.

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/predict/dog.jpeg', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-bbd66cb91f54> in <cell line: 0>()
#       1 from IPython.display import Image as IPyImage
#       2
# ----> 3 IPyImage(filename=f'{HOME}/runs/detect/predict/dog.jpeg', width=600)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %% [markdown]
# ### SDK
#
# **NOTE:** YOLO's Python interface allows for seamless integration into your Python projects, making it easy to load, run, and process the model's output.

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# 0: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 56.9ms
# Speed: 4.1ms preprocess, 56.9ms inference, 228.9ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# **NOTE:** The obtained `result` object stores information about the location, classes, and confidence levels of the detected objects.

# %%
result.boxes.xyxy
# Out:
# tensor([[3.0705e+02, 6.4341e+02, 5.2919e+02, 1.2558e+03],
#         [6.1400e+01, 2.4994e+02, 6.5165e+02, 9.7412e+02],
#         [1.7803e+00, 3.5551e+02, 6.3404e+02, 1.2788e+03],
#         [1.1933e+00, 3.5620e+02, 3.8455e+02, 1.2776e+03],
#         [6.2615e+02, 7.1818e+02, 6.9975e+02, 7.8754e+02]], device='cuda:0')

# %%
result.boxes.conf
# Out:
# tensor([0.6832, 0.6284, 0.5941, 0.3923, 0.3875], device='cuda:0')

# %%
result.boxes.cls
# Out:
# tensor([26., 16.,  0.,  0.,  2.], device='cuda:0')

# %% [markdown]
# **NOTE:** YOLO11 can be easily integrated with `supervision` using the familiar `from_ultralytics` connector.

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# ## Fine-tune YOLO11 on custom dataset

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# Create datasets directory and navigate to it
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# Install Roboflow if not installed
# !pip install -q roboflow

# Import necessary libraries
import os
from roboflow import Roboflow

# Set API key securely
os.environ["ROBOFLOW_API_KEY"] = "i7NYyBViBLjNwtlIAOOF"

# Initialize Roboflow
rf = Roboflow(api_key=os.environ["ROBOFLOW_API_KEY"])

# Set your dataset details
workspace_id = "glazze-workspace"         # Your workspace ID
project_id = "marine-litter-dataset"      # Your project ID
version_number = 8                        # Your dataset version number

# Access dataset
project = rf.workspace(workspace_id).project(project_id)
version = project.version(version_number)

# Download dataset in YOLOv11 format
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Marine-Litter-Dataset-8 in yolov11:: 100%|██████████| 9902/9902 [00:04<00:00, 2003.04it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True save_period=1 project='/content/drive/My Drive/YOLOv11_models'
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.3.94 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !mkdir -p "/content/drive/My Drive/YOLOv11_models/runs/train/"
# !cp -r /content/runs/detect/train/weights "/content/drive/My Drive/YOLOv11_models/runs/train/"

# %%
# !ls "/content/drive/My Drive/YOLOv11_models/runs/train/weights/"
# Out:
# best.pt  last.pt

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    labels.jpg	      train_batch1.jpg
# events.out.tfevents.1742478191.388154c71ab5.7278.0  results.csv       train_batch2.jpg
# labels_correlogram.jpg				    train_batch0.jpg  weights

# %%
from IPython.display import Image as IPyImage

IPyImage(filename='/content/drive/MyDrive/YOLOv11_models/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename='/content/drive/MyDrive/YOLOv11_models/train/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename='/content/drive/MyDrive/YOLOv11_models/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate fine-tuned model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/Marine-Litter-Dataset-8/valid/labels.cache... 983 images, 334 backgrounds, 0 corrupt: 100% 983/983 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 62/62 [00:14<00:00,  4.40it/s]
#                    all        983       3030      0.695      0.656      0.712      0.383
# Speed: 0.6ms preprocess, 8.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/500 /content/datasets/Marine-Litter-Dataset-8/test/images/image_20241004_084616_330519_jpg.rf.810d7cae9b26f3ca6a9975f14c6fdc25.jpg: 640x640 17 garbages, 15.7ms
# image 2/500 /content/datasets/Marine-Litter-Dataset-8/test/images/image_20241004_084624_332168_jpg.rf.ac3f19cf965410a403300f9ec6bf4020.jpg: 640x640 9 garbages, 15.8ms
# image 3/500 /content/datasets/Marine-Litter-Dataset-8/test/images/image_20241004_084626_335501_jpg.rf.306b24616a7cae042d331b47265f4628.jpg: 640x640 4 garbages, 15.7ms
# image 4/500 /content/datasets/Marine-Litter-Dataset-8/test/images/image_20241004_084641_539304_jpg.rf.5f50ee5dd2b5ddd29c13e7aac55d54d5.jpg: 640x640 1 garbage, 15.7ms
# ...

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob(f'{HOME}/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv11 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv11 weights.

# %%
# Uninstall current version of ultralytics
# !pip uninstall -y ultralytics

# Install the required version (8.0.196)
# !pip install ultralytics==8.0.196

# Restart the runtime (This ensures the newly installed version takes effect)
import os
os.kill(os.getpid(), 9)  # Force runtime restart

# After runtime restart, re-import the necessary libraries and deploy model

# Import necessary libraries
import os
from roboflow import Roboflow
import ultralytics

# Set your API key securely
os.environ["ROBOFLOW_API_KEY"] = "i7NYyBViBLjNwtlIAOOF"

# Initialize Roboflow
rf = Roboflow(api_key=os.environ["ROBOFLOW_API_KEY"])

# Set dataset details
workspace_id = "glazze-workspace"
project_id = "marine-litter-dataset"
version_number = 8

# Access dataset
project = rf.workspace(workspace_id).project(project_id)
version = project.version(version_number)

# Define model path (Ensure training has been completed)
model_path = "/content/runs/detect/train/weights/best.pt"

# Verify if the trained model exists
if os.path.isfile(model_path):
    print("✅ Model file exists. Deploying...")

    # Deploy model using YOLOv8 (or YOLOv5 if applicable)
    version.deploy(model_type="yolov8", model_path=model_path)
else:
    print("❌ Model file missing! Check training output.")
# Out:
# Found existing installation: ultralytics 8.3.40
# Uninstalling ultralytics-8.3.40:
#   Successfully uninstalled ultralytics-8.3.40
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 19.4 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y ultralytics
# Out:
# Found existing installation: ultralytics 8.0.196
# Uninstalling ultralytics-8.0.196:
#   Successfully uninstalled ultralytics-8.0.196

# %%
# !pip install ultralytics>=8.3.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Define the path to the folder you want to create in Google Drive
drive_folder_path = '/content/drive/My Drive/your_folder_name'

# Create the folder if it doesn't exist
if not os.path.exists(drive_folder_path):
    os.makedirs(drive_folder_path)

print(f"✅ Folder created at {drive_folder_path}")
# Out:
# ✅ Folder created at /content/drive/My Drive/your_folder_name

# %%
import shutil

# Define the path where the model will be saved in Google Drive
drive_model_path = '/content/drive/My Drive/your_folder_name/best.pt'

# Copy the model to Google Drive
shutil.copy('/content/runs/detect/train/weights/best.pt', drive_model_path)

print(f"✅ Model saved to Google Drive at {drive_model_path}")
# Out:
# ✅ Model saved to Google Drive at /content/drive/My Drive/your_folder_name/best.pt

# %%
# !pip install ultralytics>=8.3.0 --upgrade

# %%
import os

# Correct model path
model_path = "/content/runs/detect/train/weights/best.pt"

# Check if the model exists
if os.path.isfile(model_path):
    print(f"✅ Model file exists: {model_path}. Deploying...")

    try:
        # Deploy model using YOLOv8
        version.deploy(model_type="yolov11", model_path=model_path)
        print("✅ Model deployed successfully.")
    except Exception as e:
        print(f"❌ Deployment failed with error: {e}")
else:
    print("❌ Model file missing or path is incorrect. Check training output.")
# Out:
# ✅ Model file exists: /content/runs/detect/train/weights/best.pt. Deploying...
# ❌ Deployment failed with error: name 'version' is not defined

# %%
# !pip install inference

# %%
import os, random, cv2
import supervision as sv
import IPython
import inference

model_id = project.id.split("/")[1] + "/" + dataset.version
model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))

# Location of test set images
test_set_loc = dataset.location + "/test/images/"
test_images = os.listdir(test_set_loc)

# Run inference on 4 random test images, or fewer if fewer images are available
for img_name in random.sample(test_images, min(4, len(test_images))):
    print("Running inference on " + img_name)

    # Load image
    image = cv2.imread(os.path.join(test_set_loc, img_name))

    # Perform inference
    results = model.infer(image, confidence=0.4, overlap=30)[0]
    detections = sv.Detections.from_inference(results)

    # Annotate boxes and labels
    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()
    annotated_image = box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    _, ret = cv2.imencode('.jpg', annotated_image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
